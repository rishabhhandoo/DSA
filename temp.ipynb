# %%
# Paste this entire cell into Jupyter and run.
import re
from collections import defaultdict
from functools import lru_cache
import sys

def parse_input(filename="input.txt"):
    with open(filename, "r") as f:
        lines = [ln.rstrip("\n") for ln in f]

    # Parse shapes: lines starting with "<idx>:" then shape rows until next index or blank line
    shapes = {}
    i = 0
    while i < len(lines):
        ln = lines[i].strip()
        if ln == "":
            i += 1
            continue
        m = re.match(r"^(\d+):\s*$", ln)
        if not m:
            break
        idx = int(m.group(1))
        i += 1
        shape_lines = []
        while i < len(lines):
            if lines[i].strip() == "":
                i += 1
                break
            if re.match(r"^\d+:\s*$", lines[i].strip()):
                break
            if re.match(r"^\d+x\d+:\s*", lines[i].strip()):  # start of regions
                break
            shape_lines.append(lines[i])
            i += 1
        shapes[idx] = shape_lines

    # Parse regions: remaining non-empty lines like "WxH: c0 c1 c2 ..."
    regions = []
    while i < len(lines):
        ln = lines[i].strip()
        i += 1
        if not ln:
            continue
        m = re.match(r"^(\d+)x(\d+):\s*(.*)$", ln)
        if not m:
            continue
        w = int(m.group(1))
        h = int(m.group(2))
        counts = [int(x) for x in m.group(3).split()]
        regions.append((w, h, counts))
    return shapes, regions

# Convert shape visual to set of (x,y) coordinates (x = col, y = row), normalized to min 0
def shape_to_coords(shape_lines):
    coords = []
    for y, row in enumerate(shape_lines):
        for x, ch in enumerate(row):
            if ch == "#":
                coords.append((x, y))
    if not coords:
        return frozenset()
    minx = min(x for x, y in coords)
    miny = min(y for x, y in coords)
    norm = frozenset(((x - minx, y - miny) for x, y in coords))
    return norm

def rotate90(coords):
    # rotate 90 degrees: (x,y) -> (y, -x) then normalize
    pts = [(y, -x) for x, y in coords]
    minx = min(x for x, y in pts)
    miny = min(y for x, y in pts)
    return frozenset(((x - minx, y - miny) for x, y in pts))

def flip_horizontal(coords):
    # reflect horizontally: (x,y) -> (-x, y)
    pts = [(-x, y) for x, y in coords]
    minx = min(x for x, y in pts)
    miny = min(y for x, y in pts)
    return frozenset(((x - minx, y - miny) for x, y in pts))

def generate_orientations(coords):
    # generate all unique rotations/flips
    s = set()
    cur = coords
    for r in range(4):
        if cur not in s:
            s.add(cur)
        f = flip_horizontal(cur)
        if f not in s:
            s.add(f)
        cur = rotate90(cur)
    return list(s)

def get_bbox(coords):
    xs = [x for x, y in coords]
    ys = [y for x, y in coords]
    return max(xs)+1, max(ys)+1  # width, height

def can_place(grid_w, grid_h, occ, shape_coords, ox, oy):
    for x, y in shape_coords:
        gx, gy = ox + x, oy + y
        if gx < 0 or gy < 0 or gx >= grid_w or gy >= grid_h:
            return False
        if (gx, gy) in occ:
            return False
    return True

def place(occ, shape_coords, ox, oy):
    for x, y in shape_coords:
        occ.add((ox + x, oy + y))

def unplace(occ, shape_coords, ox, oy):
    for x, y in shape_coords:
        occ.remove((ox + x, oy + y))

def try_pack_one_region(grid_w, grid_h, piece_orients):
    """
    piece_orients: list of (area, [list of orientation sets for that piece]) for each piece instance
    We assume piece_orients is a list of instances (i.e., if same shape appears k times, it will appear k times in list)
    """
    # Sort pieces by area descending (and by number of orientations ascending to break ties)
    piece_indices = list(range(len(piece_orients)))
    piece_indices.sort(key=lambda i: (-piece_orients[i][0], len(piece_orients[i][1])))

    occ = set()

    # Precompute bounding dims for each orientation to limit placement loops
    orient_dims = {}
    for i in piece_indices:
        _, orients = piece_orients[i]
        od = []
        for o in orients:
            w, h = get_bbox(o)
            od.append((o, w, h))
        orient_dims[i] = od

    # backtracking
    sys.setrecursionlimit(10000)
    @lru_cache(maxsize=None)
    def occ_key_from_set(s):
        # not used; keep for potential memoization in future
        return tuple(sorted(s))

    def backtrack(k):
        if k == len(piece_indices):
            return True
        i = piece_indices[k]
        area, orients = piece_orients[i]
        # For small grids, simple heuristics suffice: try each orientation and placement
        for o, w_o, h_o in orient_dims[i]:
            # try all top-left placements that keep piece inside grid
            for ox in range(0, grid_w - w_o + 1):
                for oy in range(0, grid_h - h_o + 1):
                    if can_place(grid_w, grid_h, occ, o, ox, oy):
                        place(occ, o, ox, oy)
                        if backtrack(k + 1):
                            return True
                        unplace(occ, o, ox, oy)
        return False

    return backtrack(0)


def solve_all(shapes_raw, regions):
    # prepare shapes: index -> all orientations (sets of coords)
    shapes_coords = {}
    for idx, lines in shapes_raw.items():
        coords = shape_to_coords(lines)
        shapes_coords[idx] = generate_orientations(coords)

    success_count = 0
    results = []

    for region_idx, (w, h, counts) in enumerate(regions):
        # Build list of piece instances to place
        piece_instances = []
        valid = True
        for shape_idx, cnt in enumerate(counts):
            if cnt <= 0:
                continue
            if shape_idx not in shapes_coords:
                # shape not present in shapes section -> cannot place
                valid = False
                break
            orients = shapes_coords[shape_idx]
            # compute area of shape (same for all orientations)
            if len(orients) == 0:
                area = 0
            else:
                area = len(next(iter(orients)))
            for _ in range(cnt):
                piece_instances.append((area, orients))
        if not valid:
            results.append(False)
            continue

        # quick area-prune: total area must be <= grid area
        total_area = sum(area for area, _ in piece_instances)
        if total_area > w * h:
            results.append(False)
            continue

        # Attempt packing (try both orientations of width/height since input width x length [they mean width x height]
        # We'll treat w as width (x) and h as height (y).
        ok = try_pack_one_region(w, h, piece_instances)
        results.append(bool(ok))
        if ok:
            success_count += 1

    return success_count, results

if __name__ == "__main__":
    shapes, regions = parse_input("input.txt")
    success_count, results = solve_all(shapes, regions)
    print(f"Regions that can fit all presents: {success_count} of {len(regions)}")
    for idx, res in enumerate(results):
        print(f" Region {idx+1}: {'Fits' if res else 'Does NOT fit'}")
# Out:
# Regions that can fit all presents: 579 of 1000
#  Region 1: Fits
#  Region 2: Fits
#  Region 3: Fits
#  Region 4: Does NOT fit
#  Region 5: Does NOT fit
#  Region 6: Fits
#  Region 7: Fits
#  Region 8: Fits
#  Region 9: Fits
#  Region 10: Fits
#  Region 11: Fits
#  Region 12: Does NOT fit
#  Region 13: Does NOT fit
#  Region 14: Fits
#  Region 15: Does NOT fit
#  Region 16: Fits
#  Region 17: Fits
#  Region 18: Does NOT fit
#  Region 19: Does NOT fit
#  Region 20: Fits
#  Region 21: Does NOT fit
#  Region 22: Does NOT fit
#  Region 23: Does NOT fit
#  Region 24: Does NOT fit
#  Region 25: Does NOT fit
#  Region 26: Does NOT fit
#  Region 27: Does NOT fit
#  Region 28: Fits
#  Region 29: Does NOT fit
#  Region 30: Fits
#  Region 31: Does NOT fit
#  Region 32: Fits
#  Region 33: Fits
#  Region 34: Does NOT fit
#  Region 35: Fits
#  Region 36: Does NOT fit
#  Region 37: Fits
#  Region 38: Does NOT fit
#  Region 39: Does NOT fit
#  Region 40: Fits
#  Region 41: Fits
#  Region 42: Does NOT fit
#  Region 43: Fits
#  Region 44: Fits
#  Region 45: Does NOT fit
#  Region 46: Does NOT fit
#  Region 47: Fits
#  Region 48: Fits
#  Region 49: Fits
#  Region 50: Does NOT fit
#  Region 51: Fits
#  Region 52: Fits
#  Region 53: Fits
#  Region 54: Does NOT fit
#  Region 55: Does NOT fit
#  Region 56: Fits
#  Region 57: Does NOT fit
#  Region 58: Does NOT fit
#  Region 59: Fits
#  Region 60: Does NOT fit
#  Region 61: Does NOT fit
#  Region 62: Fits
#  Region 63: Fits
#  Region 64: Fits
#  Region 65: Fits
#  Region 66: Fits
#  Region 67: Does NOT fit
#  Region 68: Fits
#  Region 69: Fits
#  Region 70: Fits
#  Region 71: Fits
#  Region 72: Fits
#  Region 73: Fits
#  Region 74: Does NOT fit
#  Region 75: Does NOT fit
#  Region 76: Does NOT fit
#  Region 77: Does NOT fit
#  Region 78: Fits
#  Region 79: Fits
#  Region 80: Fits
#  Region 81: Fits
#  Region 82: Fits
#  Region 83: Does NOT fit
#  Region 84: Fits
#  Region 85: Fits
#  Region 86: Fits
#  Region 87: Does NOT fit
#  Region 88: Does NOT fit
#  Region 89: Fits
#  Region 90: Does NOT fit
#  Region 91: Fits
#  Region 92: Does NOT fit
#  Region 93: Does NOT fit
#  Region 94: Fits
#  Region 95: Does NOT fit
#  Region 96: Fits
#  Region 97: Fits
#  Region 98: Fits
#  Region 99: Does NOT fit
#  Region 100: Fits
#  Region 101: Does NOT fit
#  Region 102: Does NOT fit
#  Region 103: Fits
#  Region 104: Does NOT fit
#  Region 105: Fits
#  Region 106: Fits
#  Region 107: Fits
#  Region 108: Fits
#  Region 109: Fits
#  Region 110: Does NOT fit
#  Region 111: Does NOT fit
#  Region 112: Fits
#  Region 113: Fits
#  Region 114: Fits
#  Region 115: Fits
#  Region 116: Fits
#  Region 117: Fits
#  Region 118: Fits
#  Region 119: Fits
#  Region 120: Fits
#  Region 121: Fits
#  Region 122: Does NOT fit
#  Region 123: Fits
#  Region 124: Fits
#  Region 125: Does NOT fit
#  Region 126: Fits
#  Region 127: Does NOT fit
#  Region 128: Does NOT fit
#  Region 129: Does NOT fit
#  Region 130: Does NOT fit
#  Region 131: Fits
#  Region 132: Fits
#  Region 133: Does NOT fit
#  Region 134: Fits
#  Region 135: Does NOT fit
#  Region 136: Fits
#  Region 137: Fits
#  Region 138: Fits
#  Region 139: Fits
#  Region 140: Fits
#  Region 141: Does NOT fit
#  Region 142: Does NOT fit
#  Region 143: Fits
#  Region 144: Fits
#  Region 145: Fits
#  Region 146: Does NOT fit
#  Region 147: Fits
#  Region 148: Fits
#  Region 149: Does NOT fit
#  Region 150: Fits
#  Region 151: Fits
#  Region 152: Fits
#  Region 153: Fits
#  Region 154: Fits
#  Region 155: Fits
#  Region 156: Fits
#  Region 157: Fits
#  Region 158: Fits
#  Region 159: Does NOT fit
#  Region 160: Fits
#  Region 161: Fits
#  Region 162: Fits
#  Region 163: Does NOT fit
#  Region 164: Does NOT fit
#  Region 165: Does NOT fit
#  Region 166: Does NOT fit
#  Region 167: Fits
#  Region 168: Fits
#  Region 169: Fits
#  Region 170: Does NOT fit
#  Region 171: Fits
#  Region 172: Does NOT fit
#  Region 173: Does NOT fit
#  Region 174: Fits
#  Region 175: Does NOT fit
#  Region 176: Does NOT fit
#  Region 177: Does NOT fit
#  Region 178: Does NOT fit
#  Region 179: Does NOT fit
#  Region 180: Fits
#  Region 181: Does NOT fit
#  Region 182: Fits
#  Region 183: Fits
#  Region 184: Fits
#  Region 185: Does NOT fit
#  Region 186: Fits
#  Region 187: Fits
#  Region 188: Does NOT fit
#  Region 189: Does NOT fit
#  Region 190: Fits
#  Region 191: Does NOT fit
#  Region 192: Does NOT fit
#  Region 193: Does NOT fit
#  Region 194: Does NOT fit
#  Region 195: Fits
#  Region 196: Does NOT fit
#  Region 197: Does NOT fit
#  Region 198: Fits
#  Region 199: Fits
#  Region 200: Fits
#  Region 201: Fits
#  Region 202: Fits
#  Region 203: Fits
#  Region 204: Fits
#  Region 205: Does NOT fit
#  Region 206: Does NOT fit
#  Region 207: Fits
#  Region 208: Fits
#  Region 209: Does NOT fit
#  Region 210: Does NOT fit
#  Region 211: Does NOT fit
#  Region 212: Fits
#  Region 213: Does NOT fit
#  Region 214: Fits
#  Region 215: Fits
#  Region 216: Fits
#  Region 217: Fits
#  Region 218: Fits
#  Region 219: Does NOT fit
#  Region 220: Does NOT fit
#  Region 221: Fits
#  Region 222: Fits
#  Region 223: Does NOT fit
#  Region 224: Fits
#  Region 225: Fits
#  Region 226: Does NOT fit
#  Region 227: Fits
#  Region 228: Fits
#  Region 229: Does NOT fit
#  Region 230: Fits
#  Region 231: Fits
#  Region 232: Fits
#  Region 233: Does NOT fit
#  Region 234: Does NOT fit
#  Region 235: Fits
#  Region 236: Does NOT fit
#  Region 237: Does NOT fit
#  Region 238: Fits
#  Region 239: Fits
#  Region 240: Fits
#  Region 241: Does NOT fit
#  Region 242: Fits
#  Region 243: Fits
#  Region 244: Fits
#  Region 245: Fits
#  Region 246: Fits
#  Region 247: Fits
#  Region 248: Fits
#  Region 249: Does NOT fit
#  Region 250: Does NOT fit
#  Region 251: Fits
#  Region 252: Does NOT fit
#  Region 253: Does NOT fit
#  Region 254: Fits
#  Region 255: Fits
#  Region 256: Does NOT fit
#  Region 257: Fits
#  Region 258: Does NOT fit
#  Region 259: Fits
#  Region 260: Fits
#  Region 261: Fits
#  Region 262: Fits
#  Region 263: Fits
#  Region 264: Does NOT fit
#  Region 265: Does NOT fit
#  Region 266: Fits
#  Region 267: Fits
#  Region 268: Fits
#  Region 269: Fits
#  Region 270: Fits
#  Region 271: Does NOT fit
#  Region 272: Fits
#  Region 273: Does NOT fit
#  Region 274: Fits
#  Region 275: Fits
#  Region 276: Fits
#  Region 277: Fits
#  Region 278: Fits
#  Region 279: Fits
#  Region 280: Fits
#  Region 281: Fits
#  Region 282: Does NOT fit
#  Region 283: Fits
#  Region 284: Fits
#  Region 285: Does NOT fit
#  Region 286: Fits
#  Region 287: Does NOT fit
#  Region 288: Fits
#  Region 289: Does NOT fit
#  Region 290: Does NOT fit
#  Region 291: Does NOT fit
#  Region 292: Does NOT fit
#  Region 293: Fits
#  Region 294: Does NOT fit
#  Region 295: Does NOT fit
#  Region 296: Does NOT fit
#  Region 297: Fits
#  Region 298: Does NOT fit
#  Region 299: Fits
#  Region 300: Fits
#  Region 301: Does NOT fit
#  Region 302: Fits
#  Region 303: Fits
#  Region 304: Fits
#  Region 305: Fits
#  Region 306: Fits
#  Region 307: Fits
#  Region 308: Does NOT fit
#  Region 309: Fits
#  Region 310: Does NOT fit
#  Region 311: Fits
#  Region 312: Fits
#  Region 313: Fits
#  Region 314: Fits
#  Region 315: Does NOT fit
#  Region 316: Fits
#  Region 317: Fits
#  Region 318: Fits
#  Region 319: Fits
#  Region 320: Fits
#  Region 321: Fits
#  Region 322: Does NOT fit
#  Region 323: Fits
#  Region 324: Fits
#  Region 325: Does NOT fit
#  Region 326: Fits
#  Region 327: Does NOT fit
#  Region 328: Fits
#  Region 329: Fits
#  Region 330: Fits
#  Region 331: Fits
#  Region 332: Fits
#  Region 333: Fits
#  Region 334: Fits
#  Region 335: Fits
#  Region 336: Fits
#  Region 337: Does NOT fit
#  Region 338: Does NOT fit
#  Region 339: Does NOT fit
#  Region 340: Does NOT fit
#  Region 341: Fits
#  Region 342: Fits
#  Region 343: Does NOT fit
#  Region 344: Fits
#  Region 345: Does NOT fit
#  Region 346: Fits
#  Region 347: Does NOT fit
#  Region 348: Fits
#  Region 349: Fits
#  Region 350: Fits
#  Region 351: Fits
#  Region 352: Does NOT fit
#  Region 353: Does NOT fit
#  Region 354: Does NOT fit
#  Region 355: Fits
#  Region 356: Fits
#  Region 357: Does NOT fit
#  Region 358: Does NOT fit
#  Region 359: Does NOT fit
#  Region 360: Does NOT fit
#  Region 361: Fits
#  Region 362: Does NOT fit
#  Region 363: Fits
#  Region 364: Does NOT fit
#  Region 365: Fits
#  Region 366: Fits
#  Region 367: Fits
#  Region 368: Does NOT fit
#  Region 369: Does NOT fit
#  Region 370: Does NOT fit
#  Region 371: Does NOT fit
#  Region 372: Fits
#  Region 373: Fits
#  Region 374: Does NOT fit
#  Region 375: Fits
#  Region 376: Fits
#  Region 377: Fits
#  Region 378: Fits
#  Region 379: Does NOT fit
#  Region 380: Fits
#  Region 381: Does NOT fit
#  Region 382: Fits
#  Region 383: Does NOT fit
#  Region 384: Does NOT fit
#  Region 385: Does NOT fit
#  Region 386: Fits
#  Region 387: Fits
#  Region 388: Does NOT fit
#  Region 389: Fits
#  Region 390: Does NOT fit
#  Region 391: Fits
#  Region 392: Does NOT fit
#  Region 393: Fits
#  Region 394: Fits
#  Region 395: Does NOT fit
#  Region 396: Fits
#  Region 397: Fits
#  Region 398: Fits
#  Region 399: Fits
#  Region 400: Fits
#  Region 401: Fits
#  Region 402: Fits
#  Region 403: Fits
#  Region 404: Fits
#  Region 405: Fits
#  Region 406: Fits
#  Region 407: Fits
#  Region 408: Fits
#  Region 409: Does NOT fit
#  Region 410: Does NOT fit
#  Region 411: Fits
#  Region 412: Fits
#  Region 413: Fits
#  Region 414: Fits
#  Region 415: Fits
#  Region 416: Fits
#  Region 417: Does NOT fit
#  Region 418: Does NOT fit
#  Region 419: Does NOT fit
#  Region 420: Fits
#  Region 421: Does NOT fit
#  Region 422: Does NOT fit
#  Region 423: Does NOT fit
#  Region 424: Does NOT fit
#  Region 425: Does NOT fit
#  Region 426: Fits
#  Region 427: Fits
#  Region 428: Fits
#  Region 429: Fits
#  Region 430: Fits
#  Region 431: Does NOT fit
#  Region 432: Does NOT fit
#  Region 433: Fits
#  Region 434: Does NOT fit
#  Region 435: Does NOT fit
#  Region 436: Fits
#  Region 437: Fits
#  Region 438: Fits
#  Region 439: Fits
#  Region 440: Does NOT fit
#  Region 441: Does NOT fit
#  Region 442: Fits
#  Region 443: Does NOT fit
#  Region 444: Fits
#  Region 445: Fits
#  Region 446: Fits
#  Region 447: Fits
#  Region 448: Does NOT fit
#  Region 449: Does NOT fit
#  Region 450: Does NOT fit
#  Region 451: Does NOT fit
#  Region 452: Does NOT fit
#  Region 453: Fits
#  Region 454: Fits
#  Region 455: Does NOT fit
#  Region 456: Fits
#  Region 457: Fits
#  Region 458: Fits
#  Region 459: Fits
#  Region 460: Does NOT fit
#  Region 461: Fits
#  Region 462: Fits
#  Region 463: Fits
#  Region 464: Fits
#  Region 465: Fits
#  Region 466: Fits
#  Region 467: Does NOT fit
#  Region 468: Fits
#  Region 469: Fits
#  Region 470: Fits
#  Region 471: Does NOT fit
#  Region 472: Does NOT fit
#  Region 473: Does NOT fit
#  Region 474: Does NOT fit
#  Region 475: Does NOT fit
#  Region 476: Fits
#  Region 477: Fits
#  Region 478: Fits
#  Region 479: Does NOT fit
#  Region 480: Fits
#  Region 481: Does NOT fit
#  Region 482: Does NOT fit
#  Region 483: Fits
#  Region 484: Fits
#  Region 485: Fits
#  Region 486: Does NOT fit
#  Region 487: Fits
#  Region 488: Does NOT fit
#  Region 489: Does NOT fit
#  Region 490: Fits
#  Region 491: Does NOT fit
#  Region 492: Fits
#  Region 493: Does NOT fit
#  Region 494: Fits
#  Region 495: Does NOT fit
#  Region 496: Fits
#  Region 497: Fits
#  Region 498: Does NOT fit
#  Region 499: Fits
#  Region 500: Fits
#  Region 501: Fits
#  Region 502: Does NOT fit
#  Region 503: Fits
#  Region 504: Does NOT fit
#  Region 505: Fits
#  Region 506: Does NOT fit
#  Region 507: Does NOT fit
#  Region 508: Fits
#  Region 509: Does NOT fit
#  Region 510: Fits
#  Region 511: Does NOT fit
#  Region 512: Fits
#  Region 513: Does NOT fit
#  Region 514: Fits
#  Region 515: Does NOT fit
#  Region 516: Fits
#  Region 517: Fits
#  Region 518: Does NOT fit
#  Region 519: Fits
#  Region 520: Does NOT fit
#  Region 521: Does NOT fit
#  Region 522: Does NOT fit
#  Region 523: Fits
#  Region 524: Fits
#  Region 525: Fits
#  Region 526: Does NOT fit
#  Region 527: Does NOT fit
#  Region 528: Does NOT fit
#  Region 529: Does NOT fit
#  Region 530: Does NOT fit
#  Region 531: Does NOT fit
#  Region 532: Fits
#  Region 533: Fits
#  Region 534: Does NOT fit
#  Region 535: Fits
#  Region 536: Fits
#  Region 537: Fits
#  Region 538: Does NOT fit
#  Region 539: Fits
#  Region 540: Fits
#  Region 541: Does NOT fit
#  Region 542: Fits
#  Region 543: Fits
#  Region 544: Fits
#  Region 545: Fits
#  Region 546: Fits
#  Region 547: Fits
#  Region 548: Does NOT fit
#  Region 549: Does NOT fit
#  Region 550: Fits
#  Region 551: Does NOT fit
#  Region 552: Fits
#  Region 553: Fits
#  Region 554: Fits
#  Region 555: Fits
#  Region 556: Fits
#  Region 557: Fits
#  Region 558: Fits
#  Region 559: Does NOT fit
#  Region 560: Fits
#  Region 561: Does NOT fit
#  Region 562: Fits
#  Region 563: Fits
#  Region 564: Fits
#  Region 565: Does NOT fit
#  Region 566: Fits
#  Region 567: Fits
#  Region 568: Does NOT fit
#  Region 569: Does NOT fit
#  Region 570: Fits
#  Region 571: Fits
#  Region 572: Fits
#  Region 573: Does NOT fit
#  Region 574: Fits
#  Region 575: Does NOT fit
#  Region 576: Fits
#  Region 577: Does NOT fit
#  Region 578: Does NOT fit
#  Region 579: Fits
#  Region 580: Fits
#  Region 581: Fits
#  Region 582: Fits
#  Region 583: Fits
#  Region 584: Fits
#  Region 585: Does NOT fit
#  Region 586: Fits
#  Region 587: Fits
#  Region 588: Does NOT fit
#  Region 589: Does NOT fit
#  Region 590: Fits
#  Region 591: Does NOT fit
#  Region 592: Does NOT fit
#  Region 593: Fits
#  Region 594: Fits
#  Region 595: Fits
#  Region 596: Does NOT fit
#  Region 597: Does NOT fit
#  Region 598: Does NOT fit
#  Region 599: Fits
#  Region 600: Fits
#  Region 601: Does NOT fit
#  Region 602: Fits
#  Region 603: Does NOT fit
#  Region 604: Does NOT fit
#  Region 605: Fits
#  Region 606: Fits
#  Region 607: Fits
#  Region 608: Does NOT fit
#  Region 609: Fits
#  Region 610: Does NOT fit
#  Region 611: Fits
#  Region 612: Fits
#  Region 613: Does NOT fit
#  Region 614: Fits
#  Region 615: Does NOT fit
#  Region 616: Fits
#  Region 617: Does NOT fit
#  Region 618: Fits
#  Region 619: Fits
#  Region 620: Does NOT fit
#  Region 621: Does NOT fit
#  Region 622: Fits
#  Region 623: Does NOT fit
#  Region 624: Does NOT fit
#  Region 625: Fits
#  Region 626: Does NOT fit
#  Region 627: Fits
#  Region 628: Does NOT fit
#  Region 629: Fits
#  Region 630: Fits
#  Region 631: Fits
#  Region 632: Does NOT fit
#  Region 633: Does NOT fit
#  Region 634: Does NOT fit
#  Region 635: Fits
#  Region 636: Fits
#  Region 637: Fits
#  Region 638: Does NOT fit
#  Region 639: Fits
#  Region 640: Fits
#  Region 641: Does NOT fit
#  Region 642: Does NOT fit
#  Region 643: Does NOT fit
#  Region 644: Does NOT fit
#  Region 645: Does NOT fit
#  Region 646: Fits
#  Region 647: Fits
#  Region 648: Fits
#  Region 649: Does NOT fit
#  Region 650: Does NOT fit
#  Region 651: Fits
#  Region 652: Fits
#  Region 653: Does NOT fit
#  Region 654: Fits
#  Region 655: Fits
#  Region 656: Does NOT fit
#  Region 657: Fits
#  Region 658: Does NOT fit
#  Region 659: Does NOT fit
#  Region 660: Does NOT fit
#  Region 661: Does NOT fit
#  Region 662: Fits
#  Region 663: Does NOT fit
#  Region 664: Does NOT fit
#  Region 665: Does NOT fit
#  Region 666: Does NOT fit
#  Region 667: Does NOT fit
#  Region 668: Does NOT fit
#  Region 669: Does NOT fit
#  Region 670: Fits
#  Region 671: Does NOT fit
#  Region 672: Fits
#  Region 673: Fits
#  Region 674: Fits
#  Region 675: Does NOT fit
#  Region 676: Does NOT fit
#  Region 677: Does NOT fit
#  Region 678: Fits
#  Region 679: Fits
#  Region 680: Fits
#  Region 681: Fits
#  Region 682: Fits
#  Region 683: Fits
#  Region 684: Fits
#  Region 685: Does NOT fit
#  Region 686: Fits
#  Region 687: Does NOT fit
#  Region 688: Fits
#  Region 689: Does NOT fit
#  Region 690: Does NOT fit
#  Region 691: Fits
#  Region 692: Fits
#  Region 693: Fits
#  Region 694: Does NOT fit
#  Region 695: Does NOT fit
#  Region 696: Does NOT fit
#  Region 697: Fits
#  Region 698: Fits
#  Region 699: Does NOT fit
#  Region 700: Fits
#  Region 701: Fits
#  Region 702: Fits
#  Region 703: Does NOT fit
#  Region 704: Fits
#  Region 705: Does NOT fit
#  Region 706: Fits
#  Region 707: Does NOT fit
#  Region 708: Fits
#  Region 709: Fits
#  Region 710: Does NOT fit
#  Region 711: Does NOT fit
#  Region 712: Does NOT fit
#  Region 713: Does NOT fit
#  Region 714: Does NOT fit
#  Region 715: Fits
#  Region 716: Fits
#  Region 717: Does NOT fit
#  Region 718: Fits
#  Region 719: Fits
#  Region 720: Fits
#  Region 721: Does NOT fit
#  Region 722: Fits
#  Region 723: Does NOT fit
#  Region 724: Fits
#  Region 725: Fits
#  Region 726: Fits
#  Region 727: Does NOT fit
#  Region 728: Fits
#  Region 729: Does NOT fit
#  Region 730: Fits
#  Region 731: Fits
#  Region 732: Fits
#  Region 733: Fits
#  Region 734: Fits
#  Region 735: Does NOT fit
#  Region 736: Fits
#  Region 737: Does NOT fit
#  Region 738: Does NOT fit
#  Region 739: Fits
#  Region 740: Does NOT fit
#  Region 741: Fits
#  Region 742: Fits
#  Region 743: Fits
#  Region 744: Fits
#  Region 745: Fits
#  Region 746: Fits
#  Region 747: Fits
#  Region 748: Fits
#  Region 749: Fits
#  Region 750: Fits
#  Region 751: Does NOT fit
#  Region 752: Does NOT fit
#  Region 753: Fits
#  Region 754: Fits
#  Region 755: Does NOT fit
#  Region 756: Does NOT fit
#  Region 757: Does NOT fit
#  Region 758: Does NOT fit
#  Region 759: Does NOT fit
#  Region 760: Fits
#  Region 761: Fits
#  Region 762: Fits
#  Region 763: Does NOT fit
#  Region 764: Does NOT fit
#  Region 765: Fits
#  Region 766: Does NOT fit
#  Region 767: Does NOT fit
#  Region 768: Fits
#  Region 769: Does NOT fit
#  Region 770: Does NOT fit
#  Region 771: Does NOT fit
#  Region 772: Does NOT fit
#  Region 773: Does NOT fit
#  Region 774: Does NOT fit
#  Region 775: Does NOT fit
#  Region 776: Does NOT fit
#  Region 777: Does NOT fit
#  Region 778: Fits
#  Region 779: Does NOT fit
#  Region 780: Does NOT fit
#  Region 781: Does NOT fit
#  Region 782: Fits
#  Region 783: Fits
#  Region 784: Fits
#  Region 785: Fits
#  Region 786: Fits
#  Region 787: Does NOT fit
#  Region 788: Does NOT fit
#  Region 789: Does NOT fit
#  Region 790: Fits
#  Region 791: Does NOT fit
#  Region 792: Fits
#  Region 793: Does NOT fit
#  Region 794: Does NOT fit
#  Region 795: Fits
#  Region 796: Does NOT fit
#  Region 797: Fits
#  Region 798: Fits
#  Region 799: Does NOT fit
#  Region 800: Does NOT fit
#  Region 801: Fits
#  Region 802: Does NOT fit
#  Region 803: Fits
#  Region 804: Fits
#  Region 805: Does NOT fit
#  Region 806: Does NOT fit
#  Region 807: Does NOT fit
#  Region 808: Fits
#  Region 809: Fits
#  Region 810: Does NOT fit
#  Region 811: Does NOT fit
#  Region 812: Fits
#  Region 813: Fits
#  Region 814: Fits
#  Region 815: Fits
#  Region 816: Does NOT fit
#  Region 817: Fits
#  Region 818: Does NOT fit
#  Region 819: Fits
#  Region 820: Fits
#  Region 821: Does NOT fit
#  Region 822: Does NOT fit
#  Region 823: Fits
#  Region 824: Fits
#  Region 825: Fits
#  Region 826: Fits
#  Region 827: Fits
#  Region 828: Does NOT fit
#  Region 829: Does NOT fit
#  Region 830: Fits
#  Region 831: Fits
#  Region 832: Fits
#  Region 833: Does NOT fit
#  Region 834: Does NOT fit
#  Region 835: Fits
#  Region 836: Fits
#  Region 837: Fits
#  Region 838: Does NOT fit
#  Region 839: Fits
#  Region 840: Fits
#  Region 841: Fits
#  Region 842: Does NOT fit
#  Region 843: Fits
#  Region 844: Fits
#  Region 845: Does NOT fit
#  Region 846: Fits
#  Region 847: Does NOT fit
#  Region 848: Fits
#  Region 849: Fits
#  Region 850: Fits
#  Region 851: Does NOT fit
#  Region 852: Fits
#  Region 853: Does NOT fit
#  Region 854: Fits
#  Region 855: Fits
#  Region 856: Fits
#  Region 857: Does NOT fit
#  Region 858: Does NOT fit
#  Region 859: Does NOT fit
#  Region 860: Does NOT fit
#  Region 861: Fits
#  Region 862: Does NOT fit
#  Region 863: Fits
#  Region 864: Fits
#  Region 865: Fits
#  Region 866: Does NOT fit
#  Region 867: Does NOT fit
#  Region 868: Fits
#  Region 869: Does NOT fit
#  Region 870: Fits
#  Region 871: Fits
#  Region 872: Fits
#  Region 873: Fits
#  Region 874: Does NOT fit
#  Region 875: Fits
#  Region 876: Fits
#  Region 877: Does NOT fit
#  Region 878: Does NOT fit
#  Region 879: Does NOT fit
#  Region 880: Does NOT fit
#  Region 881: Does NOT fit
#  Region 882: Fits
#  Region 883: Fits
#  Region 884: Does NOT fit
#  Region 885: Fits
#  Region 886: Does NOT fit
#  Region 887: Fits
#  Region 888: Does NOT fit
#  Region 889: Fits
#  Region 890: Fits
#  Region 891: Fits
#  Region 892: Fits
#  Region 893: Does NOT fit
#  Region 894: Does NOT fit
#  Region 895: Does NOT fit
#  Region 896: Fits
#  Region 897: Does NOT fit
#  Region 898: Does NOT fit
#  Region 899: Fits
#  Region 900: Fits
#  Region 901: Does NOT fit
#  Region 902: Fits
#  Region 903: Fits
#  Region 904: Fits
#  Region 905: Does NOT fit
#  Region 906: Fits
#  Region 907: Does NOT fit
#  Region 908: Fits
#  Region 909: Fits
#  Region 910: Fits
#  Region 911: Does NOT fit
#  Region 912: Does NOT fit
#  Region 913: Fits
#  Region 914: Does NOT fit
#  Region 915: Does NOT fit
#  Region 916: Does NOT fit
#  Region 917: Fits
#  Region 918: Does NOT fit
#  Region 919: Does NOT fit
#  Region 920: Does NOT fit
#  Region 921: Fits
#  Region 922: Fits
#  Region 923: Does NOT fit
#  Region 924: Does NOT fit
#  Region 925: Fits
#  Region 926: Fits
#  Region 927: Does NOT fit
#  Region 928: Fits
#  Region 929: Fits
#  Region 930: Fits
#  Region 931: Does NOT fit
#  Region 932: Fits
#  Region 933: Does NOT fit
#  Region 934: Fits
#  Region 935: Does NOT fit
#  Region 936: Does NOT fit
#  Region 937: Does NOT fit
#  Region 938: Does NOT fit
#  Region 939: Fits
#  Region 940: Fits
#  Region 941: Does NOT fit
#  Region 942: Does NOT fit
#  Region 943: Fits
#  Region 944: Fits
#  Region 945: Fits
#  Region 946: Does NOT fit
#  Region 947: Fits
#  Region 948: Fits
#  Region 949: Does NOT fit
#  Region 950: Fits
#  Region 951: Does NOT fit
#  Region 952: Fits
#  Region 953: Does NOT fit
#  Region 954: Fits
#  Region 955: Fits
#  Region 956: Fits
#  Region 957: Fits
#  Region 958: Fits
#  Region 959: Does NOT fit
#  Region 960: Fits
#  Region 961: Does NOT fit
#  Region 962: Fits
#  Region 963: Fits
#  Region 964: Does NOT fit
#  Region 965: Does NOT fit
#  Region 966: Fits
#  Region 967: Fits
#  Region 968: Does NOT fit
#  Region 969: Does NOT fit
#  Region 970: Fits
#  Region 971: Does NOT fit
#  Region 972: Fits
#  Region 973: Fits
#  Region 974: Fits
#  Region 975: Does NOT fit
#  Region 976: Fits
#  Region 977: Fits
#  Region 978: Fits
#  Region 979: Fits
#  Region 980: Does NOT fit
#  Region 981: Does NOT fit
#  Region 982: Fits
#  Region 983: Does NOT fit
#  Region 984: Does NOT fit
#  Region 985: Does NOT fit
#  Region 986: Fits
#  Region 987: Fits
#  Region 988: Fits
#  Region 989: Does NOT fit
#  Region 990: Fits
#  Region 991: Fits
#  Region 992: Fits
#  Region 993: Does NOT fit
#  Region 994: Fits
#  Region 995: Fits
#  Region 996: Fits
#  Region 997: Fits
#  Region 998: Fits
#  Region 999: Does NOT fit
#  Region 1000: Fits
